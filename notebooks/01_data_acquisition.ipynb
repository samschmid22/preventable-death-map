# %% [markdown]
# # 01 Data Acquisition
#
# ## Objective
#
# Collect the core public datasets needed to analyze premature mortality across U.S. counties.
#
# ## First Dataset
#
# The first dataset will be county-level premature mortality from CDC WONDER for 2015–2019.
#
# ## Target Outcome
#
# Premature mortality rate: deaths under age 75 per 100,000 county residents.
#
# ## Baseline Period
#
# 2015–2019 will be used as the pre-COVID baseline.
#
# ## COVID Sensitivity Plan
#
# Later analyses will compare the baseline against 2020–2022 pandemic-era mortality using multiple definitions: all premature deaths, deaths excluding COVID-19 as the underlying cause, and deaths excluding any COVID-19 mention on the death certificate.

# %%
import pandas as pd
import numpy as np
from pathlib import Path

RAW_DIR = Path('../data/raw')
PROCESSED_DIR = Path('../data/processed')

RAW_DIR, PROCESSED_DIR
